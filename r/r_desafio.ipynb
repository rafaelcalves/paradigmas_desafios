# %% [markdown]
# # Linguagem 3 - R

# %% [markdown]
# Integrantes do grupo:
# * <font color=red>**Nome Completo do Integrante 1**</font>
# * <font color=red>**Nome Completo do Integrante 2**</font>
# * ...

# %% [markdown]
# Resumo das etapas:
# 1. Preparação: aprender um pouco sobre a linguagem
# 2. Desafio: resolva um desafio utilizando a linguagem
# 3. Desafio para outros grupos: crie um desafio (com resposta) para os outros grupos
#
# Ao final, este notebook deve ser enviado pelo Moodle.

# %% [markdown]
# ***
#
# ## 1. Preparação
#
# Faça o tutorial de R a seguir: https://www.tutorialspoint.com/execute_r_online.php. Como referência, é possível utilizar ainda a seguinte documentação: https://cran.r-project.org/doc/manuals/r-release/R-intro.html. Utilize a célula abaixo para testar o código do tutorial. Logo após, verifique e entenda o funcionamento dos exemplos a seguir.

# %%
# exercite seus conhecimentos de R aqui

# %% [markdown]
# ### Exemplo 1

# %%
d = read.table('lotr_data.csv', sep=',', header=T, fill=T, quote="\"")
d

# %%
plot(d$gender)
# Out:
# plot without title

# %%
unique(d$gender) #valores distintos
table(d$gender) #frequencia dos valores
# Out:
# [1] Female           Male                              Males
# [5] Most likely male male
# Levels:  Female Male Males Most likely male male
#                            Female             Male            Males
#              143              135              630                1
# Most likely male             male
#                1                1

# %%
# normaliza os gêneros
d$gender <- as.character(d$gender)
d$gender[d$gender %in% c("Males", "male", "Most likely male")]<- "Male"
d$gender[d$gender == ""] <- "Undefined"
d$gender <- as.factor(d$gender)

unique(d$gender) #valores distintos
table(d$gender) #frequencia dos valores
plot(d$gender)
# Out:
# [1] Female    Male      Undefined
# Levels: Female Male Undefined
#    Female      Male Undefined
#       135       633       143
# plot without title

# %% [markdown]
# ### Exemplo 2

# %%
unique(d$race) 
table(d$race)
# Out:
#  [1] Men              Orcs             Dragon           Elves
#  [5]                  Hobbits          Dwarves          Dragons
#  [9] Great Spiders    Black Uruk       Maiar            Ainur
# [13] Hobbit           Raven            Men,Wraith       Elf
# [17] God              Wolfhound        Half-elven       Men,Rohirrim
# [21] Maiar,Balrog     Werewolves       Dwarven          Goblin,Orc
# [25] Horse            Orc              Eagles           Uruk-hai
# [29] Great Eagles     Men,Skin-changer Maiar,Balrogs    Uruk-hai,Orc
# [33] Orc,Goblin       Elves,Noldor     Drúedain         Urulóki
# [37] Ents,Onodrim     Skin-changer     Ents             Elves,Maiar
# [41] Balrog           Eagle            Dwarf            Stone-trolls
# [45] Vampire          Men,Undead       Half-elven,Men   Ainur,Maiar
# 48 Levels:  Ainur Ainur,Maiar Balrog Black Uruk Dragon Dragons ... Wolfhound
#                             Ainur      Ainur,Maiar           Balrog
#              140               24                1                1
#       Black Uruk           Dragon          Dragons         Drúedain
#                1                1                5                1
#            Dwarf          Dwarven          Dwarves            Eagle
#                1                1               42                1
#           Eagles              Elf            Elves      Elves,Maiar
#                1                3              103                1
#     Elves,Noldor             Ents     Ents,Onodrim       Goblin,Orc
#                1                2                1                1
#              God     Great Eagles    Great Spiders       Half-elven
#                1                2                2                7
#   Half-elven,Men           Hobbit          Hobbits            Horse
#                1               16              126                1
#            Maiar     Maiar,Balrog    Maiar,Balrogs              Men
#                4                1                1              388
#     Men,Rohirrim Men,Skin-changer       Men,Undead       Men,Wraith
#                1                1                1                3
#              Orc       Orc,Goblin             Orcs            Raven
#                4                1                6                1
#     Skin-changer     Stone-trolls         Uruk-hai     Uruk-hai,Orc
#                1                1                3                1
#          Urulóki          Vampire       Werewolves        Wolfhound
#                1                1                2                1

# %%
# normalizar as raças que se referem a homens
d$race <- as.character(d$race)
d$race[d$race %in% unique(d$race[grepl("Men", d$race)])] <- "Men"
d$race <- as.factor(d$race)

unique(d$race) 
table(d$race)
# Out:
#  [1] Men           Orcs          Dragon        Elves
#  [6] Hobbits       Dwarves       Dragons       Great Spiders Black Uruk
# [11] Maiar         Ainur         Hobbit        Raven         Elf
# [16] God           Wolfhound     Half-elven    Maiar,Balrog  Werewolves
# [21] Dwarven       Goblin,Orc    Horse         Orc           Eagles
# [26] Uruk-hai      Great Eagles  Maiar,Balrogs Uruk-hai,Orc  Orc,Goblin
# [31] Elves,Noldor  Drúedain      Urulóki       Ents,Onodrim  Skin-changer
# [36] Ents          Elves,Maiar   Balrog        Eagle         Dwarf
# [41] Stone-trolls  Vampire       Ainur,Maiar
# 43 Levels:  Ainur Ainur,Maiar Balrog Black Uruk Dragon Dragons ... Wolfhound
#                       Ainur   Ainur,Maiar        Balrog    Black Uruk
#           140            24             1             1             1
#        Dragon       Dragons      Drúedain         Dwarf       Dwarven
#             1             5             1             1             1
#       Dwarves         Eagle        Eagles           Elf         Elves
#            42             1             1             3           103
#   Elves,Maiar  Elves,Noldor          Ents  Ents,Onodrim    Goblin,Orc
#             1             1             2             1             1
#           God  Great Eagles Great Spiders    Half-elven        Hobbit
#             1             2             2             7            16
#       Hobbits         Horse         Maiar  Maiar,Balrog Maiar,Balrogs
#           126             1             4             1             1
#           Men           Orc    Orc,Goblin          Orcs         Raven
#           395             4             1             6             1
#  Skin-changer  Stone-trolls      Uruk-hai  Uruk-hai,Orc       Urulóki
#             1             1             3             1             1
#       Vampire    Werewolves     Wolfhound
#             1             2             1

# %% [markdown]
# ### Exemplo 3

# %%
# cria uma nova coluna com o nome "nova"
d$dead <- F
d
# Out:
#     birth
# 1
# 2   TA 2978
# 3
# 4   TA 280
# 5
# 6   SA 2709
# 7
# 8   YT
# 9
# 10  SA 3219
# 11  SA 3118
# 12  SA 2876
# 13  SA 2960
# 14  TA 2866
# 15
# 16  Late ,Third Age
# 17  Perhaps ,Firstborn
# 18
# 19
# 20
# 21  Early ,First Age
# 22  TA 654
# 23  SA 2277
# 24  SA 1320
# 25  SA 2136
# 26  SA 1174
# 27  SA 3035
# 28  SA 3117
# 29  SA 1474
# 30  SA 350
# ⋮   ⋮
# 882 Possibly before the Creation of Arda
# 883 Late ,Third Age
# 884 TA 136
# 885 YT
# 886 TA 2994
# 887
# 888
# 889 Years of the Trees
# 890 Years of the Trees
# 891 TA 726
# 892
# 893 Sometime during ,Years of the Trees, or the ,First Age
# 894 YT
# 895 Late ,Second Age
# 896 TA 3017
# 897 Between ,SA 700, and ,SA 750
# 898 Between ,SA 700, and ,SA 750
# 899
# 900 Late ,First Age
# 901 TA 2544
# 902 TA 1330
# 903 Before the creation of Arda
# 904 TA 2827
# 905
# 906
# 907 Mid ,First Age
# 908
# 909 YT during the ,Noontide of Valinor
# 910 TA 2917
# 911 Before ,TA 1944
#     death                                   gender
# 1                                           Female
# 2   February 26 ,3019                       Male
# 3   March ,3019                             Male
# 4   TA 515                                  Male
# 5                                           Male
# 6   SA 2962                                 Male
# 7                                           Male
# 8   FA 455                                  Male
# 9                                           Undefined
# 10  SA 3440                                 Male
# 11  Still alive                             Male
# 12  SA 3102                                 Male
# 13  SA 3177                                 Male
# 14  TA 2977                                 Male
# 15                                          Undefined
# 16                                          Male
# 17                                          Undefined
# 18                                          Undefined
# 19                                          Undefined
# 20  FA 510                                  Male
# 21                                          Male
# 22  TA 913                                  Male
# 23  SA 2637                                 Female
# 24  SA 1731                                 Female
# 25  SA 2526                                 Male
# 26  SA 1574                                 Male
# 27  SA 3255                                 Male
# 28  SA 3319                                 Female
# 29  SA 1873                                 Male
# 30  SA 751                                  Male
# ⋮   ⋮                                       ⋮
# 882 FA 587                                  Male
# 883                                         Male
# 884 TA 411                                  Male
# 885                                         Female
# 886                                         Male
# 887                                         Undefined
# 888 TA 1981                                 Male
# 889 YT 1497 ,Losgar                         Male
# 890 FA 538                                  Male
# 891 TA 946                                  Male
# 892                                         Undefined
# 893 SA 3434                                 Male
# 894 Still alive                             Female
# 895 Sailed West either SA 3310 fate unknown Male
# 896 FO 95                                   Male
# 897 Early ,Second Age                       Female
# 898 Early ,Second Age                       Female
# 899                                         Female
# 900 FA 489                                  Male
# 901 TA 2645                                 Male
# 902 TA 1540                                 Male
# 903                                         Male
# 904 TA 2932                                 Male
# 905                                         Undefined
# 906                                         Undefined
# 907 FA 495                                  Female
# 908                                         Undefined
# 909 FA 455                                  Male
# 910 TA 3010                                 Male
# 911 Late ,Third Age                         Male
#     hair                            height
# 1
# 2   Dark (book) Light brown (movie)
# 3
# 4
# 5
# 6
# 7
# 8   Golden
# 9
# 10
# 11                                  Tall
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 20                                  Tall
# 21                                  Tallest of the Elves of Gondolin
# 22
# 23
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# ⋮   ⋮                               ⋮
# 882                                 As tall as a mountain
# 883 Dark
# 884
# 885
# 886
# 887
# 888 Golden
# 889 Dark red
# 890 Dark red
# 891
# 892
# 893
# 894
# 895
# 896
# 897
# 898
# 899
# 900
# 901
# 902
# 903
# 904
# 905
# 906
# 907
# 908
# 909 Golden
# 910
# 911
#     name                      race        realm
# 1   Adanel                    Men
# 2   Boromir                   Men
# 3   Lagduf                    Orcs
# 4   Tarcil                    Men         Arnor
# 5   Fire-drake of Gondolin    Dragon
# 6   Ar-Adûnakhôr              Men         Númenor
# 7   Annael                    Elves
# 8   Angrod                    Elves
# 9   Angrim
# 10  Anárion                   Men         Gondor
# 11  Ar-Pharazôn               Men         Númenor
# 12  Ar-Sakalthôr              Men         Númenor
# 13  Ar-Gimilzôr               Men         Númenor
# 14  Angelimir                 Men
# 15  Angelimar
# 16  Angbor                    Men
# 17  Nurwë                     Elves
# 18  Linda (Baggins) Proudfoot
# 19  Bodo Proudfoot
# 20  Penlod                    Elves
# 21  Pengolodh                 Elves
# 22  Tarannon Falastur         Men         Gondor
# 23  Tar-Vanimeldë             Men         Númenor
# 24  Tar-Telperiën             Men         Númenor
# 25  Tar-Telemmaitë            Men         Númenor
# 26  Tar-Súrion                Men         Númenor
# 27  Tar-Palantir              Men         Númenor
# 28  Tar-Míriel                Men         Númenor
# 29  Tar-Minastir              Men         Númenor
# 30  Tar-Elendil               Men         Númenor
# ⋮   ⋮                         ⋮           ⋮
# 882 Ancalagon                 Dragons
# 883 Anborn                    Men
# 884 Anardil                   Men         Gondor
# 885 Anairë                    Elves
# 886 Amrothos                  Men
# 887 Andvír
# 888 Amroth                    Elves       Lórien
# 889 Amrod                     Elves
# 890 Amras                     Elf         Estolad
# 891 Amlaith                   Men         Arthedain
# 892 Amlach
# 893 Amdír                     Elves       Lórien
# 894 Amarië                    Elves
# 895 Amandil                   Men
# 896 Alphros                   Men
# 897 Almiel                    Men
# 898 Ailinel                   Men
# 899 Almarian                  Men         Númenor
# 900 Algund                    Men
# 901 Aldor                     Men         Rohan
# 902 Aldamir                   Men         Gondor
# 903 Alatar                    Ainur,Maiar
# 904 Aglahad                   Men
# 905 Aghan
# 906 Agathor
# 907 Aerin                     Men
# 908 Aerandir
# 909 Aegnor                    Elves
# 910 Adrahil II                Men
# 911 Adrahil I                 Men
#     spouse                                                dead
# 1   Belemir                                               FALSE
# 2                                                         FALSE
# 3                                                         FALSE
# 4   Unnamed wife                                          FALSE
# 5                                                         FALSE
# 6   Unnamed wife                                          FALSE
# 7                                                         FALSE
# 8   Eldalótë                                              FALSE
# 9                                                         FALSE
# 10  Unnamed wife                                          FALSE
# 11  Tar-Míriel                                            FALSE
# 12  Unnamed wife                                          FALSE
# 13  Inzilbêth                                             FALSE
# 14  Unnamed wife                                          FALSE
# 15                                                        FALSE
# 16                                                        FALSE
# 17                                                        FALSE
# 18                                                        FALSE
# 19                                                        FALSE
# 20                                                        FALSE
# 21                                                        FALSE
# 22  Berúthiel                                             FALSE
# 23  Herucalmo                                             FALSE
# 24  None                                                  FALSE
# 25  Unnamed wife                                          FALSE
# 26  Unnamed wife                                          FALSE
# 27  Unnamed wife                                          FALSE
# 28  Ar-Pharazôn                                           FALSE
# 29  Unnamed wife                                          FALSE
# 30  Unnamed wife                                          FALSE
# ⋮   ⋮                                                     ⋮
# 882                                                       FALSE
# 883                                                       FALSE
# 884 Unnamed wife                                          FALSE
# 885 Fingolfin                                             FALSE
# 886                                                       FALSE
# 887                                                       FALSE
# 888 Nimrodel                                              FALSE
# 889 None                                                  FALSE
# 890 None                                                  FALSE
# 891 Unnamed wife                                          FALSE
# 892                                                       FALSE
# 893 Unnamed wife                                          FALSE
# 894 Loved ,Finrod, but it is unknown whether they married FALSE
# 895 Unnamed wife                                          FALSE
# 896                                                       FALSE
# 897                                                       FALSE
# 898 Orchaldor                                             FALSE
# 899 Tar-Meneldur                                          FALSE
# 900 None known                                            FALSE
# 901 Unnamed wife                                          FALSE
# 902 Unnamed wife                                          FALSE
# 903 None                                                  FALSE
# 904 Unnamed wife                                          FALSE
# 905                                                       FALSE
# 906                                                       FALSE
# 907 Brodda                                                FALSE
# 908                                                       FALSE
# 909 Loved ,Andreth but remained unmarried                 FALSE
# 910 Unnamed wife                                          FALSE
# 911                                                       FALSE

# %%
# altera a coluna dead para TRUE para todos indivíduos que já morreram
for (r in 1:nrow(d)) {
    if(d[r,]$death != "") {
        d[r,]$dead = T 
    }
}
table(d$dead)
d
# Out:
# FALSE  TRUE
#   315   596
#     birth
# 1
# 2   TA 2978
# 3
# 4   TA 280
# 5
# 6   SA 2709
# 7
# 8   YT
# 9
# 10  SA 3219
# 11  SA 3118
# 12  SA 2876
# 13  SA 2960
# 14  TA 2866
# 15
# 16  Late ,Third Age
# 17  Perhaps ,Firstborn
# 18
# 19
# 20
# 21  Early ,First Age
# 22  TA 654
# 23  SA 2277
# 24  SA 1320
# 25  SA 2136
# 26  SA 1174
# 27  SA 3035
# 28  SA 3117
# 29  SA 1474
# 30  SA 350
# ⋮   ⋮
# 882 Possibly before the Creation of Arda
# 883 Late ,Third Age
# 884 TA 136
# 885 YT
# 886 TA 2994
# 887
# 888
# 889 Years of the Trees
# 890 Years of the Trees
# 891 TA 726
# 892
# 893 Sometime during ,Years of the Trees, or the ,First Age
# 894 YT
# 895 Late ,Second Age
# 896 TA 3017
# 897 Between ,SA 700, and ,SA 750
# 898 Between ,SA 700, and ,SA 750
# 899
# 900 Late ,First Age
# 901 TA 2544
# 902 TA 1330
# 903 Before the creation of Arda
# 904 TA 2827
# 905
# 906
# 907 Mid ,First Age
# 908
# 909 YT during the ,Noontide of Valinor
# 910 TA 2917
# 911 Before ,TA 1944
#     death                                   gender
# 1                                           Female
# 2   February 26 ,3019                       Male
# 3   March ,3019                             Male
# 4   TA 515                                  Male
# 5                                           Male
# 6   SA 2962                                 Male
# 7                                           Male
# 8   FA 455                                  Male
# 9                                           Undefined
# 10  SA 3440                                 Male
# 11  Still alive                             Male
# 12  SA 3102                                 Male
# 13  SA 3177                                 Male
# 14  TA 2977                                 Male
# 15                                          Undefined
# 16                                          Male
# 17                                          Undefined
# 18                                          Undefined
# 19                                          Undefined
# 20  FA 510                                  Male
# 21                                          Male
# 22  TA 913                                  Male
# 23  SA 2637                                 Female
# 24  SA 1731                                 Female
# 25  SA 2526                                 Male
# 26  SA 1574                                 Male
# 27  SA 3255                                 Male
# 28  SA 3319                                 Female
# 29  SA 1873                                 Male
# 30  SA 751                                  Male
# ⋮   ⋮                                       ⋮
# 882 FA 587                                  Male
# 883                                         Male
# 884 TA 411                                  Male
# 885                                         Female
# 886                                         Male
# 887                                         Undefined
# 888 TA 1981                                 Male
# 889 YT 1497 ,Losgar                         Male
# 890 FA 538                                  Male
# 891 TA 946                                  Male
# 892                                         Undefined
# 893 SA 3434                                 Male
# 894 Still alive                             Female
# 895 Sailed West either SA 3310 fate unknown Male
# 896 FO 95                                   Male
# 897 Early ,Second Age                       Female
# 898 Early ,Second Age                       Female
# 899                                         Female
# 900 FA 489                                  Male
# 901 TA 2645                                 Male
# 902 TA 1540                                 Male
# 903                                         Male
# 904 TA 2932                                 Male
# 905                                         Undefined
# 906                                         Undefined
# 907 FA 495                                  Female
# 908                                         Undefined
# 909 FA 455                                  Male
# 910 TA 3010                                 Male
# 911 Late ,Third Age                         Male
#     hair                            height
# 1
# 2   Dark (book) Light brown (movie)
# 3
# 4
# 5
# 6
# 7
# 8   Golden
# 9
# 10
# 11                                  Tall
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 20                                  Tall
# 21                                  Tallest of the Elves of Gondolin
# 22
# 23
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# ⋮   ⋮                               ⋮
# 882                                 As tall as a mountain
# 883 Dark
# 884
# 885
# 886
# 887
# 888 Golden
# 889 Dark red
# 890 Dark red
# 891
# 892
# 893
# 894
# 895
# 896
# 897
# 898
# 899
# 900
# 901
# 902
# 903
# 904
# 905
# 906
# 907
# 908
# 909 Golden
# 910
# 911
#     name                      race        realm
# 1   Adanel                    Men
# 2   Boromir                   Men
# 3   Lagduf                    Orcs
# 4   Tarcil                    Men         Arnor
# 5   Fire-drake of Gondolin    Dragon
# 6   Ar-Adûnakhôr              Men         Númenor
# 7   Annael                    Elves
# 8   Angrod                    Elves
# 9   Angrim
# 10  Anárion                   Men         Gondor
# 11  Ar-Pharazôn               Men         Númenor
# 12  Ar-Sakalthôr              Men         Númenor
# 13  Ar-Gimilzôr               Men         Númenor
# 14  Angelimir                 Men
# 15  Angelimar
# 16  Angbor                    Men
# 17  Nurwë                     Elves
# 18  Linda (Baggins) Proudfoot
# 19  Bodo Proudfoot
# 20  Penlod                    Elves
# 21  Pengolodh                 Elves
# 22  Tarannon Falastur         Men         Gondor
# 23  Tar-Vanimeldë             Men         Númenor
# 24  Tar-Telperiën             Men         Númenor
# 25  Tar-Telemmaitë            Men         Númenor
# 26  Tar-Súrion                Men         Númenor
# 27  Tar-Palantir              Men         Númenor
# 28  Tar-Míriel                Men         Númenor
# 29  Tar-Minastir              Men         Númenor
# 30  Tar-Elendil               Men         Númenor
# ⋮   ⋮                         ⋮           ⋮
# 882 Ancalagon                 Dragons
# 883 Anborn                    Men
# 884 Anardil                   Men         Gondor
# 885 Anairë                    Elves
# 886 Amrothos                  Men
# 887 Andvír
# 888 Amroth                    Elves       Lórien
# 889 Amrod                     Elves
# 890 Amras                     Elf         Estolad
# 891 Amlaith                   Men         Arthedain
# 892 Amlach
# 893 Amdír                     Elves       Lórien
# 894 Amarië                    Elves
# 895 Amandil                   Men
# 896 Alphros                   Men
# 897 Almiel                    Men
# 898 Ailinel                   Men
# 899 Almarian                  Men         Númenor
# 900 Algund                    Men
# 901 Aldor                     Men         Rohan
# 902 Aldamir                   Men         Gondor
# 903 Alatar                    Ainur,Maiar
# 904 Aglahad                   Men
# 905 Aghan
# 906 Agathor
# 907 Aerin                     Men
# 908 Aerandir
# 909 Aegnor                    Elves
# 910 Adrahil II                Men
# 911 Adrahil I                 Men
#     spouse                                                dead
# 1   Belemir                                               FALSE
# 2                                                          TRUE
# 3                                                          TRUE
# 4   Unnamed wife                                           TRUE
# 5                                                         FALSE
# 6   Unnamed wife                                           TRUE
# 7                                                         FALSE
# 8   Eldalótë                                               TRUE
# 9                                                         FALSE
# 10  Unnamed wife                                           TRUE
# 11  Tar-Míriel                                             TRUE
# 12  Unnamed wife                                           TRUE
# 13  Inzilbêth                                              TRUE
# 14  Unnamed wife                                           TRUE
# 15                                                        FALSE
# 16                                                        FALSE
# 17                                                        FALSE
# 18                                                        FALSE
# 19                                                        FALSE
# 20                                                         TRUE
# 21                                                        FALSE
# 22  Berúthiel                                              TRUE
# 23  Herucalmo                                              TRUE
# 24  None                                                   TRUE
# 25  Unnamed wife                                           TRUE
# 26  Unnamed wife                                           TRUE
# 27  Unnamed wife                                           TRUE
# 28  Ar-Pharazôn                                            TRUE
# 29  Unnamed wife                                           TRUE
# 30  Unnamed wife                                           TRUE
# ⋮   ⋮                                                     ⋮
# 882                                                        TRUE
# 883                                                       FALSE
# 884 Unnamed wife                                           TRUE
# 885 Fingolfin                                             FALSE
# 886                                                       FALSE
# 887                                                       FALSE
# 888 Nimrodel                                               TRUE
# 889 None                                                   TRUE
# 890 None                                                   TRUE
# 891 Unnamed wife                                           TRUE
# 892                                                       FALSE
# 893 Unnamed wife                                           TRUE
# 894 Loved ,Finrod, but it is unknown whether they married  TRUE
# 895 Unnamed wife                                           TRUE
# 896                                                        TRUE
# 897                                                        TRUE
# 898 Orchaldor                                              TRUE
# 899 Tar-Meneldur                                          FALSE
# 900 None known                                             TRUE
# 901 Unnamed wife                                           TRUE
# 902 Unnamed wife                                           TRUE
# 903 None                                                  FALSE
# 904 Unnamed wife                                           TRUE
# 905                                                       FALSE
# 906                                                       FALSE
# 907 Brodda                                                 TRUE
# 908                                                       FALSE
# 909 Loved ,Andreth but remained unmarried                  TRUE
# 910 Unnamed wife                                           TRUE
# 911                                                        TRUE

# %% [markdown]
# ***
#
# ## 2. Desafio

# %% [markdown]
# ### Data Scientist dos Anéis!
#
# <img src="https://i.imgur.com/GgtKfjt.jpg" style="width: 500px;"/>
#
# O Instituto de Estatísticas Históricas da Terra Média (IEHTM) precisa fazer um censo de habitantes históricos da terra média. Estas informações devem ser montadas para apresentar resultados interessantes em um congresso.
#
# Para tanto, foi feito um levantamento de uma série de habitantes relevantes para a pesquisa. O levantamento possui dados de nome, datas de nascimento/morte, gênero, raça, entre outros.
#
# Ajude o IEHTM a responder às seguintes perguntas:
# * Como é a demografia total (quantidades por raças e sexos)?
# * Qual a demografia evoluiu ao longo do tempo?
# * Qual a idade média dos habitantes de cada raça?
# * Como a idade média dos habitantes de cada raça evoluiu ao longo do tempo?
# * Qual a taxa de casamentos?
# * Como os casamentos variam de raça para raça?
# * Qual a frequência de casamentos inter-raciais?
# * Como traços (cabelo, altura) físicos se relacionam com as raças?

# %% [markdown]
# ### Instruções/regras para o desafio:
#
# Faça uma reunião com o seu grupo e organize os dados necessários para as análises. Os dados se encontram no arquivo `lotr_data.csv`.
#
# Desenvolva um programa em R que utilize os dados e faça as análises para responder às questões acima.
#
# Mais informações sobre as épocas na cronologia da história podem ser consultadas em: https://en.wikipedia.org/wiki/Timeline_of_Arda.
#
# Algumas dos comandos/estruturas que podem ser úteis:
# * Leitura do teclado com `IRuby.input`
# * Impressão na tela com `puts`
# * Conversão uma variável para inteiro `nomeVar.chomp.to_i`
# * Repetições
# * Funções
# * Operadores lógicos como `&&` e `or`
# * Criação de classes

# %% [markdown]
# ### Solução do grupo
#
# Desenvolva a solução do grupo na célula abaixo:

# %%
d = read.table('lotr_data.csv', sep=',', header=T, fill=T, quote="\"")

print("1. Como é a demografia total (quantidades por raças e sexos)?")
d$gender <- as.character(d$gender)
d$gender[d$gender %in% c("Males", "male", "Most likely male")]<- "Male"
d$gender[d$gender == ""] <- "Undefined"
d$gender <- as.factor(d$gender)
table(d$gender, d$race)

print("2. Como a demografia evoluiu ao longo do tempo??")
plot(d$birth)
# Out:
# [1] "1. Como é a demografia total (quantidades por raças e sexos)?"
#
#                 Ainur Ainur,Maiar Balrog Black Uruk Dragon Dragons Drúedain
#   Female      1    10           0      0          0      0       0        0
#   Male        2    14           1      1          1      1       5        1
#   Undefined 137     0           0      0          0      0       0        0
#
#             Dwarf Dwarven Dwarves Eagle Eagles Elf Elves Elves,Maiar
#   Female        0       0       1     0      0   0    24           1
#   Male          1       1      41     1      1   3    76           0
#   Undefined     0       0       0     0      0   0     3           0
#
#             Elves,Noldor Ents Ents,Onodrim Goblin,Orc God Great Eagles
#   Female               0    0            0          0   0            0
#   Male                 1    2            1          1   1            2
#   Undefined            0    0            0          0   0            0
#
#             Great Spiders Half-elven Half-elven,Men Hobbit Hobbits Horse Maiar
#   Female                2          2              1      5      36     0     0
#   Male                  0          5              0     11      90     0     4
#   Undefined             0          0              0      0       0     1     0
#
#             Maiar,Balrog Maiar,Balrogs Men Men,Rohirrim Men,Skin-changer
#   Female               0             0  51            0                0
#   Male                 1             1 335            1                1
#   Undefined            0             0   2            0                0
#
#             Men,Undead Men,Wraith Orc Orc,Goblin Orcs Raven Skin-changer
#   Female             0          0   0          0    0     0            0
#   Male               1          3   4          1    6     1            1
#   Undefined          0          0   0          0    0     0            0
#
#             Stone-trolls Uruk-hai Uruk-hai,Orc Urulóki Vampire Werewolves
#   Female               0        0            0       0       1          0
#   Male                 1        3            1       1       0          2
#   Undefined            0        0            0       0       0          0
#
#             Wolfhound
#   Female            0
#   Male              1
#   Undefined         0
# [1] "2. Como a demografia evoluiu ao longo do tempo??"
# plot without title

# %% [markdown]
# ***
#
# ## 3. Desafio para os outros grupos
#
# Tema da história: **filmes de aventura**.
#
# Cada grupo deve se basear em um filme e em um cenário (como no desafio do professor) e propor um desafio para os outros grupos (no estilo _beginners_!). **O conjunto de dados a ser utilizado deve ser fornecido junto do desafio.** Exemplos de datasets podem ser encontrados em https://www.kaggle.com/datasets.
#
# Ao final, os enunciados devem ser postados no fórum para desafiar os outros grupos (cada desafio deve ser escolhido por no máximo 01 grupo). Para isto, crie um novo tópico no fórum da aula de hoje com o enunciado do desafio. Não esqueça de incluir o título do desafio!

# %% [markdown]
# ### Descrição do desafio

# %% [markdown]
# (descreva seu desafio aqui)
#
# (ao final, crie um novo tópico no fórum da aula de hoje com o enunciado do desafio; não esqueça de incluir o título do desafio!)

# %% [markdown]
# ### Solução do desafio

# %%
# solução do seu desafio aqui
